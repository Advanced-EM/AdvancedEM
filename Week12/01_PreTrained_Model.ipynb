# %% [markdown]
# ### Pre-trained Models
#
# **Roberto dos Reis**<br>
# Northwestern University
#
# July/2020

# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)

# %%
# Load the VGG19 model
# https://keras.io/applications/#VGG19
model = VGG19(include_top=True, weights='imagenet')

# %%
# Define default image size for VGG19
image_size = (224, 224)

# %%
# Load the image and resize to default image size
image_path = os.path.join("Images", "bird1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
# Preprocess image for model prediction
# This step handles scaling and normalization for VGG19
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3))
plt.imshow(img)
# Out:
# Predicted: [[('n02007558', 'flamingo', 0.9688607), ('n01855672', 'goose', 0.009939614), ('n02006656', 'spoonbill', 0.008081743)]]

# %%
# Refactor above steps into reusable function
def predict(image_path):
    """Use VGG19 to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3))

# %%
image_path = os.path.join("Images", "bird2.jpg")
predict(image_path)
# Out:
# Predicted: [[('n01622779', 'great_grey_owl', 0.9346999), ('n01608432', 'kite', 0.008001425), ('n02018795', 'bustard', 0.0069829687)]]
